# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="whitegrid")
plt.style.use('tableau-colorblind10')

# %%
pbpfoc4go = pd.read_csv('../data/pbpfoc4go.csv')

# %%
# success percentages of 4th down by field position (group into 20yds)
sns.set(style="whitegrid")
plt.style.use('tableau-colorblind10')
ax = sns.countplot(x="wspd", hue="fourth_down_converted", data=pbpfoc4go)
sns.set(font_scale=1.5)
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)

# %%
pbpfoc4gomdlF = pd.read_csv('../data/pbpfoc4gomdlF.csv')

# %%
sns.set(style="whitegrid")
plt.style.use('tableau-colorblind10')
ax = sns.countplot(x="rain", hue="fourth_down_converted", data=pbpfoc4gomdlF)
sns.set(font_scale=1.5)
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)
fig = ax.get_figure()
fig.savefig('../images/rain.png')

# %%
sns.set(style="whitegrid")
plt.style.use('tableau-colorblind10')
ax = sns.countplot(x="snow", hue="fourth_down_converted", data=pbpfoc4gomdlF)
sns.set(font_scale=1.5)
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False)
