# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="whitegrid")
plt.style.use('tableau-colorblind10')

# %%
pbpfoc4go = pd.read_csv('../data/pbpfoc4go.csv')

# %%
plt.figure(figsize=(8,20))
plt.tick_params(labelsize=14)
sns.heatmap(pbpfoc4go.corr()[['fourth_down_converted']], annot=True, cmap='coolwarm');

# %%
pbpfoc4pass = pd.read_csv('../data/pbpfoc4pass.csv')

# %%
plt.figure(figsize=(8,20))
plt.tick_params(labelsize=14)
sns.heatmap(pbpfoc4pass.corr()[['fourth_down_converted']], annot=True, cmap='coolwarm');

# %%
pbpfoc4run = pd.read_csv('../data/pbpfoc4run.csv')

# %%
plt.figure(figsize=(8,20))
plt.tick_params(labelsize=14)
sns.heatmap(pbpfoc4run.corr()[['fourth_down_converted']], annot=True, cmap='coolwarm');
