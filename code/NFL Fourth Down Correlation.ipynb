# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style="whitegrid")
plt.style.use('tableau-colorblind10')

# %%
pbpfoc4 = pd.read_csv('../data/pbpfoc4.csv')

# %%
pbpfoc4.columns
# Out:
# Index(['play_id', 'game_id', 'date_id', 'home_team', 'away_team', 'posteam',
#        'posteam_type', 'defteam', 'side_of_field', 'yardline_100', 'game_date',
#        'quarter_seconds_remaining', 'half_seconds_remaining',
#        'game_seconds_remaining', 'game_half', 'quarter_end', 'drive', 'sp',
#        'qtr', 'down', 'goal_to_go', 'time', 'yrdln', 'ydstogo', 'ydsnet',
#        'desc', 'play_type', 'yards_gained', 'shotgun', 'no_huddle',
#        'qb_dropback', 'qb_scramble', 'pass_length', 'pass_location',
#        'air_yards', 'yards_after_catch', 'run_location', 'run_gap',
#        'home_timeouts_remaining', 'away_timeouts_remaining', 'timeout',
#        'timeout_team', 'td_team', 'posteam_timeouts_remaining',
#        'defteam_timeouts_remaining', 'total_home_score', 'total_away_score',
#        'posteam_score', 'defteam_score', 'score_differential',
#        'posteam_score_post', 'defteam_score_post', 'score_differential_post',
#        'first_down_rush', 'first_down_pass', 'first_down_penalty',
#        'third_down_converted', 'third_down_failed', 'fourth_down_converted',
#        'fourth_down_failed', 'incomplete_pass', 'interception',
#        'fumble_forced', 'fumble_not_forced', 'fumble_out_of_bounds',
#        'solo_tackle', 'penalty', 'tackled_for_loss', 'fumble_lost', 'qb_hit',
#        'rush_attempt', 'pass_attempt', 'sack', 'touchdown', 'pass_touchdown',
#        'rush_touchdown', 'return_touchdown', 'stad', 'temp', 'humd', 'wspd',
#        'wdir', 'cond', 'surf'],
#       dtype='object')

# %%
plt.figure(figsize=(8,20))
plt.tick_params(labelsize=14)
sns.heatmap(pbpfoc4.corr()[['fourth_down_converted']], annot=True, cmap='coolwarm').sort(ascending=False);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-ba3b0f9533ab> in <module>
#       1 plt.figure(figsize=(8,20))
#       2 plt.tick_params(labelsize=14)
# ----> 3 sns.heatmap(pbpfoc4.corr()[['fourth_down_converted']], annot=True, cmap='coolwarm').sort(ascending=False);
#
# AttributeError: 'AxesSubplot' object has no attribute 'sort'
